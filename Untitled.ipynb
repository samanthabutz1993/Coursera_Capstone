# %%
import pandas as pd

# %%
mc_raw = pd.read_csv('Warmup_Pegasus.csv',sep=";")

# %%
pwd
# Out:
# '/Users/samanthabutz/Desktop'

# %%
mc_raw
# Out:
#                              550  \
# 0                CVS 1482D3/1-80
# 1                      L6FBG142R
# 2                    HW100-14636
# 3                     HW80-14829
# 4                AWMPD69LH7/1-80
# 5                     EFLS627UIW
# 6                      DWDFV5441
# 7                       WTG941B2
# 8   PEGASUS-ZRXGODRCVPOTEJFLPMPT
# 9                     NA-127MB1L
# 10                     WTW4715EW
# 11                      F4J6JY2S
# 12  PEGASUS-XFXYBXSHUPITVLEJRTZH
# 13              IWC 81252 ECO UK
#
#                                                   565  5322   5796   5805  \
# 0   http://www.candy-domestic.co.uk/en_GB/applianc...    60     52  42524
# 1   https://www.aeg.co.uk/laundry/laundry/washing-...   NaN     13  42524
# 2   http://www.haier.com/uk/consumer/laundry/washi...   NaN   59,5  42524
# 3   http://www.haier.com/uk/consumer/laundry/washi...   NaN   59,5  42524
# 4   https://www.hoover.co.uk/en_GB/front-loading-w...    60     52  42524
# ...
